# %% [markdown]
# <a href="https://colab.research.google.com/github/AngeloSorte/Customer_Support_AI_System/blob/angelosorte.github.io/Customer_Support_AI_System_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Customer Support AI System
# Author: Angelo Sorte
# Description: Simple AI chatbot for banking customer support

# ------------------------
# Imports
# ------------------------
import nltk
import random
import string

# Download necessary NLTK data
nltk.download('punkt')

# ------------------------
# Sample knowledge base
# ------------------------
responses = {
    "account": "You can check your account balance via online banking or mobile app.",
    "loan": "We offer personal, home, and auto loans. Please visit our website for details.",
    "card": "You can apply for a credit card online or at your nearest branch.",
    "support": "You can contact support at support@bank.com."
}

# ------------------------
# Preprocessing function
# ------------------------
def preprocess(text):
    text = text.lower()
    tokens = nltk.word_tokenize(text)
    return tokens

# ------------------------
# Chatbot logic
# ------------------------
def chatbot_response(user_input):
    tokens = preprocess(user_input)
    for token in tokens:
        if token in responses:
            return responses[token]
    return "I'm sorry, I didn't understand your request. Please contact support."

# ------------------------
# Chat simulation
# ------------------------
print("Customer Support AI Chatbot (type 'exit' to quit)")
while True:
    user_input = input("You: ")
    if user_input.lower() == 'exit':
        break
    response = chatbot_response(user_input)
    print("Bot:", response)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Customer Support AI Chatbot (type 'exit' to quit)
# You: exit
